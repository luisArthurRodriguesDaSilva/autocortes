# %%
from edit_video import cut_video
from dowload_video import download_video_smalest_resolution
from get_video_data import save_video_data , filter_transcript

# %%
video_id_without_legend = "zQzDSaO4tow"

keywords = ["zema", "maranhão", "governador"]
transcript = save_video_data(video_id_without_legend)
filtered_transcript, starts = filter_transcript(transcript, keywords)
# Out:
# ---------------------------------------------------------------------------
# TranscriptsDisabled                       Traceback (most recent call last)
# File ~/Área de Trabalho/repositorios/autocortes/scripts/get_video_data.py:23, in _get_transcript(video_id)
#      22 try:
# ---> 23     transcript = YouTubeTranscriptApi().fetch(video_id, languages=["pt", "pt-BR", "en"])
#      24 except Exception as e:
#      25     #quando der erro deve aparecer somente essa msg, sem o stack trace completo
#
# File ~/.local/lib/python3.11/site-packages/youtube_transcript_api/_api.py:71, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      57 """
#      58 Retrieves the transcript for a single video. This is just a shortcut for
#      59 calling:
#    (...)
#      68 :param preserve_formatting: whether to keep select HTML text formatting
#      69 """
#      70 return (
# ---> 71     self.list(video_id)
#      72     .find_transcript(languages)
# ...

# %%
download_video_smalest_resolution(video_id_without_legend)
inicio,fim =starts[0]- 5, starts[0]+5
cut_video(f"../videos inteiros/{video_id_without_legend}.mp4", inicio, fim)
